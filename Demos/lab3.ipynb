# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain.agents import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %%
class State(TypedDict):
  messages: Annotated[list, add_messages]

graph_builder = StateGraph(State)

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

# %%
# Introducing nest_asyncio
# Python async code only allows for one "event loop" processing aynchronous events.
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

import nest_asyncio
nest_asyncio.apply()

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\johng\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\johng\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\johng\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\johng\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\johng\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\johng\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\johng\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>

# %%
# Creating a dictionary for tools for easier access
tool_dict = {tool.name:tool for tool in tools} 

# Getters for the tool
navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")

    
await navigate_tool.arun({"url": "https://www.cnn.com"})
text = await extract_text_tool.arun({})

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# Breaking News, Latest News and Videos | CNN CNN values your feedback
# 1. How relevant is this ad to you? 2. Did you encounter any technical
# issues? No Video player was slow to load content Video content never
# loaded Ad froze or did not finish loading Video content did not start
# after ad Audio on ad was too loud Other issues Ad never loaded Ad
# prevented/slowed the page from loading Content moved around while ad
# loaded Ad was repetitive to ads I've seen previously Other issues
# Cancel Submit Thank You! Your effort and contribution in providing
# this feedback is much
# appreciated. Close Ad Feedback Close icon US World Politics Business
# Health Entertainment Underscored Style Travel Sports Science Climate
# Weather Ukraine-Russia War Israel-Hamas War Games More US World
# Politics Business Health Entertainment Underscored Style Travel Sports
# Science Climate Weather Ukraine-Russia War Israel-Hamas War Games
# Watch Listen Subscribe Sign in My Account Settings Newsletters Topics
# you follow Sign out Your CNN account Sign in to your CNN account Sign
# in My Account Settings Newsletters Topics you follow Sign out Your CNN
# account Sign in to your CNN account Listen Watch Edition US
# International Arabic Español Edition US International Arabic Español
# US Crime + Justice World Africa Americas Asia Australia China Europe
# India Middle East United Kingdom Politics Trump Facts First CNN Polls
# 2025 Elections Business Tech Media Calculators Videos Markets Pre-
# markets After-Hours Fear & Greed Investing Markets Now Nightcap Health
# Life, But Better Fitness Food Sleep Mindfulness Relationships CNN
# Underscored Electronics Fashion Beauty Health & Fitness Home Reviews
# Deals Gifts Travel Outdoors Pets Entertainment Movies Television
# Celebrity Tech Innovate Foreseeable Future Mission: Ahead Work
# Transformed Innovative Cities Style Arts Design Fashion Architecture
# Luxury Beauty Video Travel Destinations Food & Drink Stay Videos
# Sports Pro Football College Football Basketball Baseball Soccer
# Olympics Hockey Science Space Life Unearthed Climate Solutions Weather
# Weather Video Climate Ukraine-Russia War Israel-Hamas War Watch
# Featured Shows & Films Network TV Clips CNN Headlines CNN Shorts TV
# Shows A-Z CNN 10 CNN Max TV Schedule Listen CNN 5 Things Chasing Life
# with Dr. Sanjay Gupta The Assignment with Audie Cornish One Thing Tug
# of War CNN Political Briefing The Axe Files All There Is with Anderson
# Cooper All CNN Audio podcasts Games Daily Crossword Jumble Crossword
# Photo Shuffle Sudoblock Sudoku 5 Things Quiz About CNN Subscribe
# Photos Investigations CNN Profiles CNN Leadership CNN Newsletters Work
# for CNN Follow CNN Live Updates Epstein files Government shutdown
# Trending Newsom calls Trump an ‘invasive species’ CNN Underscored
# Gifts for men Jeffrey Epstein scandal • Analysis Analysis CNN Analysis
# Takeaways from the new Epstein emails mentioning Trump Live Updates
# Johnson says House will vote next week on whether to release Epstein
# files Jeffrey Epstein mentioned Trump in private emails, new release
# shows CNN Exclusive Trump administration holds Situation Room meeting
# over House effort to force release of all of DOJ’s Epstein files The
# Epstein files petition now has its 218th signature. What happens next?
# For Subscribers Trump and Epstein’s relationship: A visual timeline
# Rep. Adelita Grijalva is finally sworn in as the House’s newest
# Democrat, paving way for Epstein files vote House set to vote to end
# record-setting shutdown Show all • Live Updates Live Updates House TV
# Live Updates After eight Senate Democrats struck a deal with
# Republicans, the House is back in Washington to vote to reopen the
# government House takes key step forward on funding package to reopen
# government Things could get bumpy as the House reconvenes for a vote
# 1:18 • Analysis for Subscribers Analysis for Subscribers Francis
# Chung/POLITICO/AP Analysis for Subscribers House lawmakers are
# returning to Washington and to a changed world • Video 1:13
# X/@derrickvanorden Video Lawmakers rush back to DC for government
# shutdown vote 1:13 Tom Brenner/Getty Images What’s in the bill to
# reopen the federal government? CNN Photo Illustration by Patrick
# Gallagher/CNN/Getty Why not split the MMR vaccine? • Live Live Live
# Watch CNN’s live coverage Owen Humphreys/PA Wire A ‘cannibal storm’
# from the sun triggered auroras. Another round is on its way CNN
# Headlines • Source: CNN Video Watch the latest CNN Headlines British
# Transport Police British Police want to speak to a MAGA influencer and
# partner after London incident Analysis for Subscribers Affordability
# is in crisis. The solution: You’ll never own anything again Local
# station WLS: Judge orders release of hundreds arrested in Illinois
# immigration crackdown Video ‘You have arrived in hell’: Human rights
# organizations document abuses in El Salvador prison 15:11 Former aide
# to two NY governors, accused of being Chinese agent, goes on trial for
# money laundering and fraud Video Kremlin warns of ‘dangerous’ nuclear
# rhetoric 1:18 Inside Politics Nathan Ellgren/AP/File Former aide to
# California governor indicted for alleged theft of campaign funds from
# ex-health secretary Video ‘Suicide can’t be my legacy for my
# children": Sen. Fetterman reflects on recovery after his stroke led to
# severe depression 7:17 Climate crisis • For Subscribers For
# Subscribers Alexis Rosenfeld/Getty Images For Subscribers New climate
# reports show humanity is careening toward an untenable future Ad
# Feedback Ad Feedback CNN Underscored Henry T. Casey/CNN Underscored
# Beat the rush: We found 71 early Black Friday sales to grab now Nov
# 10, 2025 Joe Bloss/CNN Underscored I drove from California to Texas
# twice. These are the road trip essentials I wish I’d packed Sep 29,
# 2025 Jillian Tracy/CNN Underscored Book lovers have enough books. Get
# them one of these 30 bookish gifts instead Nov 11, 2025 Ad Feedback
# Check These Out John Lund/Image Bank Film/Getty Images The last-ever
# penny was minted today in Philadelphia Getty Images Where colossal
# stone gods guard a 2,000-year-old mystery Emily Alff/Sipa USA/AP/File
# New Epstein emails, Thanksgiving travel, the last penny: Catch up on
# the day’s stories 20th Century Studios Meryl Streep reunites with Anne
# Hathaway in ‘The Devil Wears Prada 2’ teaser: ‘Took you long enough’
# Sara Jaye/Getty Images KATSEYE say they receive thousands of death
# threats Take a closer look • Video 0:16 Bridge partially collapses in
# China Social Media/Reuters Video Bridge partially collapses in China
# 0:16 Maskot/Digital Vision/Getty Images High blood pressure isn’t just
# a problem for adults. Rates in children have nearly doubled in 20
# years KSBY A timeline of 9-year-old Melodee Buzzard’s disappearance
# and her mother’s arrest cnni People are protesting penguins’ living
# conditions in an aquarium. It’s complicated, expert says 1:15 For
# Subscribers • Analysis Analysis Apu Gomes/Getty Images Analysis
# Trump’s $2,000 tariff dividend may be a smart political move. But it
# would be a huge economic gamble • CNN Exclusive CNN Exclusive Photo
# Illustration by Alberto Mier/CNN/Getty Images CNN Exclusive Sexism at
# Hegseth’s Pentagon contributed to ousting of female elite commander,
# military insiders allege • For Subscribers For Subscribers mauritius
# images GmbH/Alamy Stock Photo For Subscribers ‘Did you vote for
# Trump?’ Americans traveling abroad are under new scrutiny • KFILE
# KFILE Andrew Roth/Sipa KFILE Michigan Senate candidate Abdul El-Sayed
# scrubbed past support for ‘defund the police’ Ad Feedback Ad Feedback
# CNN Underscored Best-in-Class Molly Flores/CNN Underscored Oprah’s
# Favorite Things list is finally here. Here are our favorite gifts to
# shop ASAP The 42 most unique gift ideas I’ve seen for the holiday
# season so far A bra shouldn’t be a pain to wear. We found 3 bras that
# passed our comfort test 9 candle warmers that will instantly make your
# home smell amazing and feel cozier The best flannel sheets to stay
# cozy when it’s cold, tried and tested Expert-Backed Guides Amina Lake
# Patel/CNN Underscored 17 affordable car upgrades that will make your
# daily commute better This week’s 10 best Amazon early Black Friday
# deals: Anker, Lego, O-Cedar and more The best base layers of 2025,
# tried and tested Skip the needles. Skin experts swear by these wrinkle
# creams to smooth fine lines The 68 best gifts for husbands in 2025, no
# matter his interests Editors' picks Henry T. Casey/CNN Underscored
# This is the best PC laptop under $500 Sweaters, leggings and coats are
# up to 60% off in Nordstrom’s early Black Friday sale We tested 10
# pairs of winter gloves. These 2 were the best we tried, and start at
# just $33 The 36 best beauty Advent calendars to grab ahead of the
# holidays The Amazon Prime Visa is offering a $250 gift card bonus
# ahead of Black Friday shopping Trump administration Graeme
# Sloan/Bloomberg/Getty Images How the Trump administration seeks to
# ‘weaponize’ the White House website to troll Democrats and amplify its
# message Andrew Caballero-Reynolds/AFP/Getty Images White House weighs
# stepped up domestic travel and speeches to improve Trump’s standing on
# the economy • Video 0:40 Fox News/The Ingraham Angle Video Trump says
# ‘I have an obligation’ to sue the BBC in Fox interview 0:40 world
# Metropolitan Police/Reuters Chinese ‘cryptoqueen’ who had royal
# aspirations jailed in UK over $6.6 billion Bitcoin scam Courtesy Al-
# Najjar family ‘A death sentence for my son’: Israel plans to deport
# sick Palestinians back to Gaza, patients and doctors say House of
# Commons/UK Parliament/Press Association via AP Rumors swirl of a plot
# to oust Keir Starmer as the embattled British leader denies attacking
# his rivals Ad Feedback US Angela Weiss/AFP/Getty Images Mega Millions
# jackpot nears $1 billion after there were no big winners in Tuesday’s
# drawing • Video 0:53 SFMTA Video Video appears to show train driver
# falling asleep 0:53 Noah Berger/AP Justice Department investigating UC
# Berkeley protests during Turning Point USA event CNN Sports Show all
# Jevone Moore/Icon Sportswire/Getty Images Donald Trump really, really
# doesn’t like the NFL’s new kickoff format Maja Hitij/Getty Images
# Europe/Getty Images for Laver Cup ‘It’s time for the men to step up’:
# Taylor Fritz, Ben Shelton seek inspiration from US women Chris
# Szagola/AP New York Giants fire head coach Brian Daboll Bleacher
# Report Show all NCAA wipes 14 wins from Michigan State’s record New
# Funko Pops revealed for NFL stars Notre Dame’s bold CFB choice paying
# off Simone Biles picks up two new sports during hiatus Pitching
# superstar rumored to want trade to Yankees CNN Shorts • Video 1:39 CNN
# Video Kenny Chesney’s connection to a Sandy Hook family 1:39 • Video
# 1:16 TVCTV Video Teen gives emotional testimony on ICE raids at city
# council meeting 1:16 • Video 2:11 Fox News Video Why Trump’s comments
# on American workers set off MAGA furor 2:11 • Video 2:35 CNN Video
# Disturbing aftermath of Israeli settler rampage 2:35 • Video 1:18
# Reuters/Getty Images Video Trump asks Israeli president to pardon
# Netanyahu 1:18 • Video 1:17 CNN Video US mints its last penny 1:17 •
# Video 1:13 X/@derrickvanorden Video Lawmakers rush back to DC for
# government shutdown vote 1:13 • Video 1:21 marimacisse57/TikTok Video
# Malian TikToker abducted and killed 1:21 • Video 2:27 CNN Video
# Officer: Military is ‘toxic’ for women 2:27 • Video 2:30 Davidoff
# Studios Photography/Archive Photos/Getty Images Video Epstein
# mentioned Trump in newly released private emails 2:30 • Video 0:27 CNN
# Video Turkish military plane falls from sky 0:27 • Video 1:01 TVN via
# Reuters Video Far-right march draws thousands in Poland 1:01 • Video
# 0:42 CNN Video Kremlin warns of ‘dangerous’ nuclear rhetoric 0:42 •
# Video 1:47 Reuters Video Why was turnout so low in Iraq’s election?
# 1:47 • Video 2:26 Natalia V. Osipova Video ‘That’s a lot of money for
# a toilet’ 2:26 • Video 1:51 DVIDS and CNN Video What the US military
# is using to strike alleged drug boats 1:51 • Video 0:39 Landon
# Moeller/TMX Video A second chance to see the northern lights 0:39 •
# Video 0:53 SFMTA Video Video appears to show train driver falling
# asleep 0:53 • Video 0:40 Fox News/The Ingraham Angle Video Trump tells
# Fox he has ‘an obligation’ to sue BBC 0:40 • Video 1:06 CNN Video CNN
# on scene at aftermath of deadliest blast in Islamabad since 2008 1:06
# • Video 1:15 CNN Video Campaigners battle for penguin freedom 1:15 •
# Video 1:44 @boldlyvictoriaa Video Travelers and staff left stranded
# after hotel chain’s sudden closure 1:44 • Video 1:37 AFP Video JFK’s
# grandson announces run for Congress 1:37 • Video 0:47 Reuters Video
# Indigenous protesters clash with COP30 security 0:47 • Video 1:13 CNN
# Video Venezuela mobilizes forces as largest US warship enters region
# 1:13 Business and Technology IBM A seismic shift in computing is on
# the horizon (and it’s not AI) • Video 4:02 POOL Video Trump claims
# affordability crisis is a democratic ‘con job’ 4:02 Brandon Bell/Getty
# Images So long, peak oil: World demand could now grow until 2050, a
# top agency says Weather and climate Adriano Machado/Reuters Newsom
# calls Trump an ‘invasive species’ and ‘wrecking ball’ in fiery remarks
# at COP30 climate summit • Video 0:16 Fronie Amador Video Typhoon
# slings suspension bridge in Philippines 0:16 • Video 0:15
# Instagram/@808hiker Video ‘Volnado’ spotted near Hawaii’s Kilauea
# volcanic eruption 0:15 Sleep better • Video 2:25 Getty Images Video
# How to put your anxious kid to bed. ‘Inside Out 2’ psychologist has
# you covered 2:25 MementoJpeg/Moment RF/Getty Images What to know about
# melatonin use and heart failure no_limit_pictures/E+/Getty Images
# Obstructive sleep apnea may be linked to microbleeds in the brain
# Style and art Sotheby's This could become one of the most expensive
# paintings ever publicly sold Raymond Hall/GC Images/Getty Images The
# necktie is back, and not just for formal events The estate of J. D.
# 'Okhai Ojeikere/Foto Ojeikere Unseen images revealed from the archive
# of Nigerian photography legend J.D. Ojeikere Travel From Sonder
# Collapse of Sonder, a Marriott-backed hotel chain, leaves guests
# stranded mid-stay Eric Lee/Bloomberg/Getty Images What’s happening
# with Thanksgiving flights? Here’s what to know N/a’an ku sê Films One
# of the world’s driest climates is producing award-winning wine Health
# and Wellness Jennifer Oosthuizen/CDC At least 27 people sickened and 6
# dead in latest US listeria outbreak. What you should know US health
# leaders hailed the benefits of hormone therapy for menopause. Doctors
# are pushing for balance ByHeart recalls all of its baby formula in the
# US amid infant botulism outbreak investigation Paid Content More from
# CNN Luxury Redefined Stephane Cardinale/Corbis/Getty Images The plume
# boom: Feathers are coming for your spring wardrobes Robert Wun Burned
# and stained, these clothes cost up to $200k 3:57 CNN After hundreds of
# hours of work, couture designer Robert Wun takes a lighter to his
# pieces Space and science Alex Davidson/Queen Mary University
# Scientists now know that bees can process time, a first in insects
# Josh Hydeman/Bat Conservation International Wind turbines kill
# millions of bats; microphones could protect them CNN Why scientists
# call these ants ‘a minefield in your backyard’ 3:11 Ad Feedback Paid
# Partner Content CNN Games + Quizzes • Sudoku Sudoku CNN Sudoku A
# cross-number crossword that will challenge your brain • Sudoblock
# Sudoblock CNN Sudoblock Sudoku + Blocks = addictive tile-matching
# puzzle • Today's crossword Today's crossword CNN Today's crossword No
# pencil or eraser required • Jumble Crossword Jumble Crossword CNN
# Jumble Crossword Test your smarts with this scrambled word game In
# case you missed it Tom Williams/CQ-Roll Call, Inc./Getty Images Jack
# Schlossberg, John F. Kennedy’s grandson, is running for US House seat
# Pope Leo shares his all-time favorite movies Officer: Military is
# ‘toxic’ for women 2:27 How a humble cabbage became one of the
# Forbidden City’s most memorable treasures Venezuela announces ‘massive
# mobilization’ of military forces as America’s largest warship sails
# into region Paris Jackson reveals she has a perforated septum Jimmy
# Kimmel pays tribute to Cleto Escobedo III, his dear friend and
# bandleader An Oklahoma sex offender vanished for 13 years after
# allegedly staging his abduction. How officials found him Subscribe
# Sign in My Account Settings Newsletters Topics you follow Sign out
# Your CNN account Sign in to your CNN account Listen Watch US Crime +
# Justice World Africa Americas Asia Australia China Europe India Middle
# East United Kingdom Politics Trump Facts First CNN Polls 2025
# Elections Business Tech Media Calculators Videos Markets Pre-markets
# After-Hours Fear & Greed Investing Markets Now Nightcap Health Life,
# But Better Fitness Food Sleep Mindfulness Relationships CNN
# Underscored Electronics Fashion Beauty Health & Fitness Home Reviews
# Deals Gifts Travel Outdoors Pets Entertainment Movies Television
# Celebrity Tech Innovate Foreseeable Future Mission: Ahead Work
# Transformed Innovative Cities Style Arts Design Fashion Architecture
# Luxury Beauty Video Travel Destinations Food & Drink Stay News Videos
# Sports Pro Football College Football Basketball Baseball Soccer
# Olympics Hockey Science Space Life Unearthed Climate Solutions Weather
# Weather Video Climate Ukraine-Russia War Israel-Hamas War Watch
# Featured Shows & Films Network TV Clips CNN Headlines CNN Shorts TV
# Shows A-Z CNN 10 CNN Max TV Schedule Listen CNN 5 Things Chasing Life
# with Dr. Sanjay Gupta The Assignment with Audie Cornish One Thing Tug
# of War CNN Political Briefing The Axe Files All There Is with Anderson
# Cooper All CNN Audio podcasts Games Daily Crossword Jumble Crossword
# Photo Shuffle Sudoblock Sudoku 5 Things Quiz About CNN Subscribe
# Photos Investigations CNN Profiles CNN Leadership CNN Newsletters Work
# for CNN Watch Listen Follow CNN Subscribe Sign in My Account Settings
# Newsletters Topics you follow Sign out Your CNN account Sign in to
# your CNN account Terms of Use Privacy Policy Manage Cookies Ad Choices
# Accessibility & CC About Subscribe Newsletters Transcripts Help Center
# © 2025 Cable News Network. A Warner Bros. Discovery Company. All
# Rights Reserved. CNN Sans ™ & © 2016 Cable News Network. Our use of
# cookies and other technologies We and our Affiliates use third parties
# to access and store data on your device to analyze use, improve your
# experience and personalize, measure and deliver ads and content.  For
# more information, visit our Privacy Policy . You can Accept All
# Cookies , or go to Cookie Settings for more choices. Cookies Settings
# Accept All Cookies Manage Cookies+ When you visit any website, it may
# store or retrieve information on your browser, mostly in the form of
# cookies. This information might be about you, your preferences or your
# device and is mostly used to make the site work as you expect it to.
# The information does not usually directly identify you, but it can
# give you a more personalized web experience. Because we respect your
# right to privacy, you can choose not to allow some types of cookies.
# Click on the different category headings to find out more and change
# our default settings. However, blocking some types of cookies may
# impact your experience of the site and the services we are able to
# offer. Privacy Policy Manage Consent Preferences Use limited data to
# select advertising Use limited data to select advertising Advertising
# presented to you on this service can be based on limited data, such as
# the website or app you are using, your non-precise location, your
# device type or which content you are (or have been) interacting with
# (for example, to limit the number of times an ad is presented to you).
# Use profiles to select personalised advertising Use profiles to select
# personalised advertising Advertising presented to you on this service
# can be based on your advertising profiles, which can reflect your
# activity on this service or other websites or apps (like the forms you
# submit, content you look at), possible interests and personal aspects.
# Create profiles for personalised advertising Create profiles for
# personalised advertising Information about your activity on this
# service (such as forms you submit, content you look at) can be stored
# and combined with other information about you (for example,
# information from your previous activity on this service and other
# websites or apps) or similar users. This is then used to build or
# improve a profile about you (that might include possible interests and
# personal aspects). Your profile can be used (also later) to present
# advertising that appears more relevant based on your possible
# interests by this and other entities. Use profiles to select
# personalised content Use profiles to select personalised content
# Content presented to you on this service can be based on your content
# personalisation profiles, which can reflect your activity on this or
# other services (for instance, the forms you submit, content you look
# at), possible interests and personal aspects. This can for example be
# used to adapt the order in which content is shown to you, so that it
# is even easier for you to find (non-advertising) content that matches
# your interests. Create profiles to personalise content Create profiles
# to personalise content Information about your activity on this service
# (for instance, forms you submit, non-advertising content you look at)
# can be stored and combined with other information about you (such as
# your previous activity on this service or other websites or apps) or
# similar users. This is then used to build or improve a profile about
# you (which might for example include possible interests and personal
# aspects). Your profile can be used (also later) to present content
# that appears more relevant based on your possible interests, such as
# by adapting the order in which content is shown to you, so that it is
# even easier for you to find content that matches your interests.
# Measure advertising performance Measure advertising performance
# Information regarding which advertising is presented to you and how
# you interact with it can be used to determine how well an advert has
# worked for you or other users and whether the goals of the advertising
# were reached. For instance, whether you saw an ad, whether you clicked
# on it, whether it led you to buy a product or visit a website, etc.
# This is very helpful to understand the relevance of advertising
# campaigns. Measure content performance Measure content performance
# Information regarding which content is presented to you and how you
# interact with it can be used to determine whether the (non-
# advertising) content e.g. reached its intended audience and matched
# your interests. For instance, whether you read an article, watch a
# video, listen to a podcast or look at a product description, how long
# you spent on this service and the web pages you visit etc. This is
# very helpful to understand the relevance of (non-advertising) content
# that is shown to you. Understand audiences through statistics or
# combinations of data from different sources Understand audiences
# through statistics or combinations of data from different sources
# Reports can be generated based on the combination of data sets (like
# user profiles, statistics, market research, analytics data) regarding
# your interactions and those of other users with advertising or (non-
# advertising) content to identify common characteristics (for instance,
# to determine which target audiences are more receptive to an ad
# campaign or to certain contents). Develop and improve services Develop
# and improve services Information about your activity on this service,
# such as your interaction with ads or content, can be very helpful to
# improve products and services and to build new products and services
# based on user interactions, the type of audience, etc. This specific
# purpose does not include the development or improvement of user
# profiles and identifiers. Ensure security, prevent and detect fraud,
# and fix errors Always Active Your data can be used to monitor for and
# prevent unusual and possibly fraudulent activity (for example,
# regarding advertising, ad clicks by bots), and ensure systems and
# processes work properly and securely. It can also be used to correct
# any problems you, the publisher or the advertiser may encounter in the
# delivery of content and ads and in your interaction with them. Deliver
# and present advertising and content Always Active Certain information
# (like an IP address or device capabilities) is used to ensure the
# technical compatibility of the content or advertising, and to
# facilitate the transmission of the content or ad to your device.
# Strictly Necessary Cookies Always Active These cookies are necessary
# for the website to function and cannot be switched off in our systems.
# You can set your browser to block or alert you about these cookies,
# but some parts of the site will not work. Back Button Cookie List
# Search Icon Filter Icon Clear checkbox label label Apply Cancel
# Consent Leg.Interest checkbox label label checkbox label label
# checkbox label label Allow All Essential Cookies Only Confirm My
# Choices

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)

def chatbot(state: State):
  return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builer = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges("chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat (user_input: str, history):
  result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
  return result["messages"][-1].content
  

gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
